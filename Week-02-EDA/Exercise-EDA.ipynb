# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
import scipy.stats as stats

df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('data/cars.csv')
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicated().sum())
# Out:
# 720

# %%
#  2. Modify our df to have all duplicate rows removed. 

print(df.shape)
# Out:
# (11914, 15)

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

df = df.drop_duplicates()
print(df.shape)
# Out:
# (11194, 15)

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?
#Engine HP has the most null values = 69
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long our dataframe is.

df.shape[0]
# Out:
# 11194

# %%
# * Remove any row that has a null value in it. 

df = df.dropna()

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.
print(df.shape)
# Out:
# (11092, 15)

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 

df1 = df["Make"].value_counts()
df1.plot(kind="bar",figsize=(20,10))

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
df1 = df["Make"].value_counts()
df1.plot(kind="barh",figsize=(20,10))

# %% [markdown]
# # Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
#gb = df.groupby('year')
MSRP_mean = gb['MSRP'].mean()
MSRP_mean.plot(kind='line', x='year', y='MSRP_mean')
#

# %%
#MSRP_mean.plot(x="Year",y="MSRP" )

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.

c1 = df['Year'] < 2000

df['adjusted_price'] = np.where( c1, df['MSRP']*10, df['MSRP'] )

df.tail()
# Multiply the MSRP by the price adjuster.
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
df_new= df.plot(kind='line', x='adjusted_price', figsize=(13,8))
df_new.set_ylim(0, 100000)
# Out:
# (0.0, 100000.0)

# %%
df.plot(kind='line', y='Year', x='adjusted_price',figsize=(13,8))

# %% [markdown]
# # What are top 5 car makers that make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# * Use our `adjusted_price` column for this
# * Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers make the most expensive cars on average. 
#adjusted_price (average) and MAKE
gb = df.groupby('Make')['adjusted_price'].mean()
new_df = pd.DataFrame(gb)
new_df = new_df.reset_index()

new_df.sort_values(by=['adjusted_price'], inplace=True,ascending=False)
new_df.head(5)
# Out:
#            Make  adjusted_price
# 6       Bugatti    1.757224e+06
# 28      Maybach    5.462219e+05
# 38  Rolls-Royce    3.511306e+05
# 22  Lamborghini    3.315673e+05
# 5       Bentley    2.471693e+05

# %% [markdown]
# # What are the 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?

gb_MPG = df.groupby('Make')['highway MPG'].median()
new_df2 = pd.DataFrame(gb_MPG)
new_df2 = new_df2.reset_index()
new_df2.sort_values(by=['highway MPG'], inplace=True,ascending=False)
new_df2.head(5)
# Out:
#           Make  highway MPG
# 1   Alfa Romeo           34
# 12        FIAT           33
# 45  Volkswagen           32
# 40       Scion           32
# 18       Honda           32

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']
# * Create a temp_df to store the dataframe of just these values.
# * Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# df['Make']== 'Chevrolet' , 'Ford', 'Toyota'
import seaborn as sns
sns.set()
#condition = df[df['Make'].isin(['Chevrolet', 'Ford', 'Toyota'])] 

temp_df = df[df['Make'].isin(['Chevrolet', 'Ford', 'Toyota'])] 
temp_df.head()
# Out:
#       Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 3644  Ford  E-150  1996  regular unleaded      199.0               6.0
# 3645  Ford  E-150  1996  regular unleaded      145.0               6.0
# 3646  Ford  E-150  1996  regular unleaded      145.0               6.0
# 3657  Ford  E-250  1996  regular unleaded      199.0               6.0
# 3658  Ford  E-250  1996  regular unleaded      145.0               6.0
#
#      Transmission Type     Driven_Wheels  Number of Doors Vehicle Size  \
# 3644         AUTOMATIC  rear wheel drive              3.0      Midsize
# 3645         AUTOMATIC  rear wheel drive              3.0      Midsize
# 3646         AUTOMATIC  rear wheel drive              3.0      Midsize
# 3657         AUTOMATIC  rear wheel drive              3.0        Large
# 3658         AUTOMATIC  rear wheel drive              3.0      Midsize
#
#       Vehicle Style  highway MPG  city mpg  Popularity  MSRP
# ...

# %%
sns.histplot(data = temp_df, 
             x = 'adjusted_price', 
             hue = 'Make')

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000

new= sns.histplot(data = temp_df, 
             x = 'adjusted_price', 
             hue = 'Make')
new.set_xlim(0,100000)

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG
relationship = sns.scatterplot(data=df, 
                               x='Engine HP',
                               y='highway MPG');

# %% [markdown]
# # Using `sns.boxplot`, create a boxplot for the 'Engine HP'

# %%
# create a boxplot for the 'Engine HP'
Engine_box = sns.boxplot(data=df, 
                         x='Engine HP');
Engine_box.set_xlim(0,800)
# Out:
# (0.0, 800.0)

# %% [markdown]
# # Make another boxplot for highway MPG

# %%
# create a boxplot for the 'highway MPG'
highway_box = sns.boxplot(data=df, 
                         x='highway MPG'
                         );
highway_box.set_xlim(0,40)
# Out:
# (0.0, 40.0)

# %% [markdown]
# # Remove any  outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# * Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# * For each column (Engine HP and highway MPG):
# * Calculate the 0.25 and 0.75 Quantiles
# * Calculate the Inter Quartile Range (IQR)
# * Create condition mask for the values that are outliers below (in the 'Minimum' range).
# * Create condition mask for the values that are outliers above (in the 'Maximum' range).
# * Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# * Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any  outliers from Engine HP and highway MPG 
Engine_Q1 = df['Engine HP'].quantile(0.25)
Engine_Q1 #172.0

Engine_Q3 = df['Engine HP'].quantile(0.75)
Engine_Q3 #303.0

Engine_IQR = Engine_Q3 - Engine_Q1
Engine_IQR #131.0

Engine_below = df['Engine HP'] < (Engine_Q1 - 1.5 * Engine_IQR)
Engine_below

Engine_above = df['Engine HP'] < (Engine_Q3 - 1.5 * Engine_IQR)
Engine_above

df2 = df[ ~(Engine_above | Engine_below) ]

# %%
highway_Q1 = df['highway MPG'].quantile(0.25)
highway_Q1 #172.0

highway_Q3 = df['highway MPG'].quantile(0.75)
highway_Q3 #303.0

highway_IQR = highway_Q3 - highway_Q1
highway_IQR #131.0

highway_below = df['highway MPG'] < (highway_Q1 - 1.5 * highway_IQR)
highway_below

highway_above = df['highway MPG'] < (highway_Q3 - 1.5 * highway_IQR)
highway_above

df3 = df[ highway_above | highway_below ]

# %% [markdown]
# # Remake the boxplots for both Engine HP and highway MPG

# %%
df['Engine HP'].describe()
# Out:
# count     171.000000
# mean      361.081871
# std       172.046862
# min       145.000000
# 25%       225.000000
# 50%       325.000000
# 75%       450.000000
# max      1001.000000
# Name: Engine HP, dtype: float64

# %%
df['highway MPG'].describe()
# Out:
# count    171.000000
# mean      14.543860
# std        0.760886
# min       12.000000
# 25%       14.000000
# 50%       15.000000
# 75%       15.000000
# max       15.000000
# Name: highway MPG, dtype: float64

# %%
# Engine HP boxplot
Engine_box = sns.boxplot(data=df2, 
                         x='Engine HP')

# %%
# highway MPG boxplot

highway_box = sns.boxplot(data=df3, 
                         x='highway MPG')

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG
x= sns.scatterplot(data=df, 
                   x='Engine HP', 
                   y='highway MPG',
                   );
x.set_ylim((0,100))
x.set_xlim((0,800))
# Out:
# (0.0, 800.0)

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?

print('The higher the Engine Hp is the the lower the value of Highway MPG. In a words, they have negative relationships with each other')
# Out:
# The higher the Engine Hp is the the lower the value of Highway MPG. In a words, they have negative relationships with each other

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
sns.pairplot(df)

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).
df.corr()
# from this correlation chart below, the relationship between MSRP and Engine Hp has the strongest linear relationship
# which is 0.813360.
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.526450          0.245030         0.203146
# Engine HP         0.526450   1.000000          0.782625        -0.264345
# Engine Cylinders  0.245030   0.782625          1.000000        -0.275842
# Number of Doors   0.203146  -0.264345         -0.275842         1.000000
# highway MPG       0.080129  -0.181969         -0.272804         0.037763
# city mpg         -0.278446  -0.738692         -0.663060         0.361077
# Popularity        0.096300  -0.213463         -0.128770        -0.177831
# MSRP              0.353862   0.813360          0.660466        -0.239684
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.080129 -0.278446    0.096300  0.353862
# Engine HP           -0.181969 -0.738692   -0.213463  0.813360
# Engine Cylinders    -0.272804 -0.663060   -0.128770  0.660466
# Number of Doors      0.037763  0.361077   -0.177831 -0.239684
# ...

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
plt.figure(figsize= (8,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

#cmap="coolwarm"

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

print('Engine HP have the strongest relationship with MSRP because the relationship between MSRP and Engine Hp is the highest closer to the 1 which is .81')
# Out:
# Engine HP have the strongest relationship with MSRP because the relationship between MSRP and Engine Hp is the highest closer to the 1 which is .81

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
